# %% [markdown]
# ## Data

# %% [markdown]
# #### Imports

# %%
from pprint import pprint
from uuid import uuid4

from tqdm import tqdm

from datetime import datetime


import os
import sys
import re
import pypandoc


from dotenv import load_dotenv


# for accesjng github api
from github import Github, Auth, ContentFile

# markdown parsing to HTML and reSt to md
from rst2gfm import convert_rst_to_md
import mistletoe

# for parsing HTML to extract links and names
import lxml
from bs4 import BeautifulSoup

# langchain for the RAG pipeline
from langchain_text_splitters import MarkdownTextSplitter, RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

from langchain_ollama import OllamaEmbeddings, ChatOllama
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI

import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy


load_dotenv()
# Out:
# True

# %% [markdown]
# #### Globals

# %%
# Context Enrichment / Summarization
OLLAMA_LANGUAGE_MODEL = "gemma3:270m"
# "gemma3:270m"
# "qwen3:1.7b"
# "qwen3:0.6b"
# "qwen2.5:0.5b"
# "gemma3:1b-it-qat"
LANGUAGE_MODEL_TEMPERATURE = 0.1
LANGUAGE_MODEL_REASONING = False

# Embedding
OLLAMA_EMBEDDING_MODEL = "embeddinggemma:300m"
TOKEN_CONTEXT_LENGTH = 1024
DOCUMENT_PREFIX = f"title: none | text: "
DOCUMENT_PREFIX_WITH_TITLE = lambda x : f"title: {x if x is not None else 'none'} | text: "
QUERY_PREFIX = "task: search result | query: "

# %% [markdown]
# #### Auth

# %%
gh_token = os.getenv("GITHUB_TOKEN") 

auth = Auth.Token(token = gh_token) # type: ignore

gh = Github(auth=auth)

print(f"Logged in as: {gh.get_user().login}")
# Out:
# Logged in as: VladBonciu

# %% [markdown]
# #### Link Extraction

# %%
awesome_lists = \
[
    "vinta/awesome-python",
    "josephmisiti/awesome-machine-learning",
    "sorrycc/awesome-javascript",
    "sindresorhus/awesome-nodejs",
    "enaqx/awesome-react",
    "vuejs/awesome-vue",
    "nepaul/awesome-web-development",
    "sbilly/awesome-security",
    "oxnr/awesome-bigdata",
    # "JStumpp/awesome-android",
    # "vsouza/awesome-ios",
    # "gztchan/awesome-design",
    "wmariuss/awesome-devops",
    "Kiloreux/awesome-robotics",
    "awesome-selfhosted/awesome-selfhosted",
    "fffaraz/awesome-cpp",
    "agarrharr/awesome-cli-apps"
]

structured = {}

all_links = []

for route in awesome_lists:

    repo = gh.get_repo(route)

    print("Extracting links from:", repo.name)

    file_content = repo.get_readme() # type: ignore

    # extract the raw markdown of the awesome list readme
    readme_content = file_content.decoded_content.decode("utf-8")  # type: ignore

    # parse it into a html formatted string
    rendered = mistletoe.markdown(readme_content)

    # parse the html string  using bs
    soup = BeautifulSoup(rendered, features='lxml')

    # repos extraction process
    tech_lists = soup.select("ul")

    dict_tech_lists = {}

    for tech_list in tech_lists:
        
        links = []

        try:

            # (sub)title of list
            subtitle = tech_list.find_all_previous()[0].text.splitlines()[0]

            for item in tech_list.select("li"):
                
                link : str = item.a.get("href", None)  # type: ignore
                
                if link.startswith("#"):
                    continue

                # im currently ignoring the other "awesomez-..." lists featured
                if "awesome-" in link:
                    # print("\t---",link.replace("https://github.com/", ""), "---")
                    continue

                if link.startswith("https://github.com/"):
                    
                    if link.endswith("/"):
                        link = link[:-1]

                    link = link.replace("https://github.com/", "")

                    link = "/".join(link.split("/")[:2])

                    if link.count("/") != 1:
                        continue

                    if link in all_links:
                        continue

                    links.append(link)
                    all_links.append(link)


        except:

            continue


        if len(links) > 0:

            # remove duplicates
            links = list(dict.fromkeys(links))

            dict_tech_lists.update({subtitle : links})

            # print(subtitle)
            # pprint(links)

    # pprint(dict_tech_lists)

    structured.update({repo.name : dict_tech_lists})

print("Done!")

print(len(all_links))
# Out:
# Extracting links from: awesome-python
# Extracting links from: awesome-machine-learning
# Extracting links from: awesome-javascript
# Extracting links from: awesome-nodejs
# Extracting links from: awesome-react
# Extracting links from: awesome-vue
# Extracting links from: awesome-web-development
# Extracting links from: awesome-security
# Extracting links from: awesome-bigdata
# Extracting links from: awesome-devops
# Extracting links from: awesome-robotics
# Extracting links from: awesome-selfhosted
# Extracting links from: awesome-cpp
# Extracting links from: awesome-cli-apps
# Done!
# 4994

# %%
# pprint(structured, sort_dicts=False)

gh.rate_limiting
# datetime.strptime(str(gh.rate_limiting_resettime), '%Y%m%d') 
print(gh.rate_limiting_resettime)

datetime.fromtimestamp(gh.rate_limiting_resettime)
# Out:
# 1767972090
# datetime.datetime(2026, 1, 9, 17, 21, 30)

# %% [markdown]
# #### Repo Parsing and Processing

# %%
def get_clean_md(readme_file):

    name = readme_file.name.lower()

    content = readme_file.decoded_content.decode("utf-8")
    
    # strip YAML front matter (if exists)
    content = re.sub(r'^---\s*\n.*?\n---\s*\n', '', content, flags=re.DOTALL)

    # find format for pandoc
    ext_map = \
    {
        '.rst': 'rst',
        '.adoc': 'asciidoc',
        '.asciidoc': 'asciidoc',
        '.textile': 'textile',
        '.org': 'org',
        '.md': 'markdown',
        '.markdown': 'markdown'
    }
    
    # get extension, default to 'markdown'
    from_format = 'markdown'
    for ext, fmt in ext_map.items():
        if name.endswith(ext):
            from_format = fmt
            break

    # convert anything to md first
    try:
        raw_md = pypandoc.convert_text(content, 'gfm-raw_html', format=from_format)
    except:
        # fallback 
        raw_md = content 

    # remove Images: ![alt](url)
    clean_md = re.sub(r'!\[.*?\]\(.*?\)', r' ', raw_md)

    # convert links to plain text: [Text](url) -> Text
    clean_md = re.sub(r'\[([^\]]+)\]\([^\)]+\)', r'\1', clean_md)

    # remove reST artifacts that Pandoc might have left over
    clean_md = re.sub(r'(?m)^\s*(\.\.\ |:)(image|target|alt|align|width|height):.*$', '', clean_md)
    
    # Remove any leftover unknown HTML tags (like <details> or <div>)
    clean_md = re.sub(r'<[^>]+>', '', clean_md)

    # this finds lines with whitespace and turns them into true empty lines
    clean_md = re.sub(r'(?m)^[ \t]+$', '', clean_md) 
    clean_md = re.sub(r'\n{3,}', '\n\n', clean_md)
    
    return clean_md.strip()

# %%
import json
import pickle
from pathlib import Path

# simple checkpoint system
CHECKPOINT_DIR = Path("checkpoints")
CHECKPOINT_DIR.mkdir(exist_ok=True)

def load_progress():
    """Load which repos were already processed."""
    checkpoint_file = CHECKPOINT_DIR / "processed_repos.json"
    if checkpoint_file.exists():
        with open(checkpoint_file, 'r') as f:
            return set(json.load(f))
    return set()

def save_progress(processed_repos):
    """Save which repos have been processed."""
    checkpoint_file = CHECKPOINT_DIR / "processed_repos.json"
    with open(checkpoint_file, 'w') as f:
        json.dump(list(processed_repos), f)

def load_documents():
    """Load previously processed documents."""
    summary_file = CHECKPOINT_DIR / "summary_docs.pkl"
    docs_file = CHECKPOINT_DIR / "docs.pkl"
    
    summary_docs = []
    docs = []
    
    if summary_file.exists():
        with open(summary_file, 'rb') as f:
            summary_docs = pickle.load(f)
    
    if docs_file.exists():
        with open(docs_file, 'rb') as f:
            docs = pickle.load(f)
    
    return summary_docs, docs

def save_documents(summary_docs, docs):
    """Save processed documents."""
    with open(CHECKPOINT_DIR / "summary_docs.pkl", 'wb') as f:
        pickle.dump(summary_docs, f)
    
    with open(CHECKPOINT_DIR / "docs.pkl", 'wb') as f:
        pickle.dump(docs, f)

# Main processing code with checkpoints
text_splitter = MarkdownTextSplitter\
(
    chunk_size=TOKEN_CONTEXT_LENGTH - 80, # -80 ish tokens for the embedding prefix and the summarization of the repo
    chunk_overlap=128,
)

# %%
# Load previous progress
processed_repos = load_progress()
summary_docs, docs = load_documents()

print(f"Already processed: {len(processed_repos)} repos")
print(f"Loaded: {len(summary_docs)} summary docs, {len(docs)} repo docs")

llm = ChatOllama \
(
    model= OLLAMA_LANGUAGE_MODEL,
    temperature = LANGUAGE_MODEL_TEMPERATURE,
    reasoning = LANGUAGE_MODEL_REASONING,
    num_predict = 2000,
    keep_alive="24h"
)

save_counter = 0
SAVE_EVERY = 10  # Save progress every 10 repos



for awesome_list_name, sublists_dict in structured.items():

    print(f"\n --- {awesome_list_name} --- \n")

    for sublist_name, repo_list in sublists_dict.items():
        
        print(f"* {sublist_name}")

        for repo_path in repo_list:

            if repo_path in processed_repos:
                continue

            try:

                repo = gh.get_repo(repo_path)
                
                readme_file = repo.get_readme() # type: ignore

                md_content = get_clean_md(readme_file=readme_file)

                # cut the md content to the first 8000 chars
                md_content = md_content[:8000]

                # initial chunks of repo
                repo_chunks = text_splitter.split_text(md_content)

                # summarization llm
                llm_reponse = llm.invoke \
                (
                    input = \
                    [
                        # SystemMessage("You are an expert software engineer, with afinities for discovering new technologies."),
                        HumanMessage(f"""Write a one-paragraph summary (6-7 sentences) of the repository content provided below. 

STRICT RULES:
1. NO PREAMBLE. Do not say "Here is" or "The text is". 
2. FIRST SENTENCE MUST BE: [Name] is a [Type] that [Z], built in [Language].
3. Output the one paragraph ONLY. (no enters / other markdown)

---
CONTENT:
{md_content}
---
SUMMARY: """),
AIMessage(f"{repo.name} is")
                    ]
                )

                # special summary doc
                summary_doc = Document \
                (
                    page_content = str(DOCUMENT_PREFIX_WITH_TITLE(repo.name) + f"{repo.name} is" + str(llm_reponse.content)),
                    metadata = \
                    { 
                        "awesome_list_origin" : awesome_list_name ,
                        "sublist_origin" : sublist_name , 
                        "repo_origin" : repo_path, 
                        "repo_name" : repo.name, 
                        "repo_description" : repo.description,
                        "repo_star_count" : repo.stargazers_count, 
                        "repo_fork_count" : repo.forks_count,
                        "repo_license_name" : repo.license.name if repo.license is not None else "-",
                        "repo_last_update_date" : repo.updated_at,
                        "repo_archived" : repo.archived
                    }
                )

                summary_docs.append(summary_doc)

                # only use the first 10 chunks , as if there were more chunks for each then  there would be a disproportionate amount of chunks for some repos
                repo_chunks = repo_chunks[:10]

                # pprint(repo_chunks, width=1000)

                # context enrichment on the  repo chunks for better retrieval
                repo_chunks = [ f"{DOCUMENT_PREFIX_WITH_TITLE(repo.name)}[{repo.name} is{str(llm_reponse.content).split(sep ='.')[0]}]\n{original_chunk}" for original_chunk in repo_chunks ]

                # print(summary_doc.page_content)
                # print(summary_doc.metadata)

                repo_docs = text_splitter.create_documents\
                (
                    texts = repo_chunks, 
                    metadatas = list(
                    { 
                        "awesome_list_origin" : awesome_list_name ,
                        "sublist_origin" : sublist_name , 
                        "repo_origin" : repo_path, 
                        "repo_name" : repo.name, 
                        "repo_description" : repo.description,
                        "repo_star_count" : repo.stargazers_count, 
                        "repo_fork_count" : repo.forks_count,
                        "repo_license_name" : repo.license.name if repo.license is not None else "-",
                        "repo_license_link" : repo.license.url if repo.license is not None else "-",
                        "repo_last_update_date" : repo.updated_at,
                        "repo_archived" : repo.archived
                    } for i in range(len(repo_chunks)))
                )



                docs.extend(repo_docs)

                processed_repos.add(repo_path)

                # Save progress periodically
                save_counter += 1
                if save_counter % SAVE_EVERY == 0:
                    save_progress(processed_repos)
                    save_documents(summary_docs, docs)
                    print(f" 💾 Progress saved ({len(processed_repos)} repos)")

                print(f" - {repo_path} ({len(repo_chunks)})")

                # sys.exit(0)
            
            except KeyboardInterrupt:
                print("\n⚠️  Interrupted! Saving progress...")
                save_progress(processed_repos)
                save_documents(summary_docs, docs)
                print(f"💾 Progress saved. Processed: {len(processed_repos)} repos")
                print("You can resume by running this cell again.")
                raise
                
            except Exception as e:

                print(f" x {repo_path}: {str(e)[:50]}")
                processed_repos.add(repo_path)  # Mark as processed even if failed
                continue
            

pprint(docs)
# Out:
# Already processed: 475 repos
# Loaded: 483 summary docs, 4315 repo docs
#
#  --- awesome-python ---
#
# * Libraries for administrative interfaces.
#  - unfoldadmin/django-unfold (8)
#  - offerrall/FuncToWeb (8)
# * awesome-algorithms
# * ASGI
#
# ⚠️  Interrupted! Saving progress...
# 💾 Progress saved. Processed: 477 repos
# You can resume by running this cell again.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 50
#      47                 repo_chunks = text_splitter.split_text(md_content)
#      49                 # summarization llm
# ---> 50                 llm_reponse = llm.invoke \
#      51                 (
#      52                     input = \
#      53                     [
#      54                         # SystemMessage("You are an expert software engineer, with afinities for discovering new technologies."),
#      55                         HumanMessage(f"""Write a one-paragraph summary (6-7 sentences) of the repository content provided below.
#      56
#      57 STRICT RULES:
#      58 1. NO PREAMBLE. Do not say "Here is" or "The text is".
#      59 2. FIRST SENTENCE MUST BE: [Name] is a [Type] that [Z], built in [Language].
#      60 3. Output the one paragraph ONLY. (no enters / other markdown)
#      61
#      62 ---
#      63 CONTENT:
#      64 {md_content}
#      65 ---
#      66 SUMMARY: """),
#      67 AIMessage(f"{repo.name} is")
#      68                     ]
#      69                 )
#      71                 # special summary doc
#      72                 summary_doc = Document \
#      73                 (
#      74                     page_content = str(DOCUMENT_PREFIX_WITH_TITLE(repo.name) + f"{repo.name} is" + str(llm_reponse.content)),
#    (...)
#      87                     }
#      88                 )
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)
#     395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:1121, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1112 @override
#    1113 def generate_prompt(
#    1114     self,
#    (...)
#    1118     **kwargs: Any,
#    1119 ) -> LLMResult:
#    1120     prompt_messages = [p.to_messages() for p in prompts]
# -> 1121     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:931, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     928 for i, m in enumerate(input_messages):
#     929     try:
#     930         results.append(
# --> 931             self._generate_with_cache(
#     932                 m,
#     933                 stop=stop,
#     934                 run_manager=run_managers[i] if run_managers else None,
#     935                 **kwargs,
#     936             )
#     937         )
#     938     except BaseException as e:
#     939         if run_managers:
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:1225, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1223     result = generate_from_stream(iter(chunks))
#    1224 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1225     result = self._generate(
#    1226         messages, stop=stop, run_manager=run_manager, **kwargs
#    1227     )
#    1228 else:
#    1229     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_ollama\chat_models.py:1030, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1023 def _generate(
#    1024     self,
#    1025     messages: list[BaseMessage],
#    (...)
#    1028     **kwargs: Any,
#    1029 ) -> ChatResult:
# -> 1030     final_chunk = self._chat_stream_with_aggregation(
#    1031         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1032     )
#    1033     generation_info = final_chunk.generation_info
#    1034     chat_generation = ChatGeneration(
#    1035         message=AIMessage(
#    1036             content=final_chunk.text,
#    (...)
#    1043         generation_info=generation_info,
#    1044     )
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_ollama\chat_models.py:965, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     956 def _chat_stream_with_aggregation(
#     957     self,
#     958     messages: list[BaseMessage],
#    (...)
#     962     **kwargs: Any,
#     963 ) -> ChatGenerationChunk:
#     964     final_chunk = None
# --> 965     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     966         if final_chunk is None:
#     967             final_chunk = chunk
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_ollama\chat_models.py:1054, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1047 def _iterate_over_stream(
#    1048     self,
#    1049     messages: list[BaseMessage],
#    1050     stop: list[str] | None = None,
#    1051     **kwargs: Any,
#    1052 ) -> Iterator[ChatGenerationChunk]:
#    1053     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1054     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1055         if not isinstance(stream_resp, str):
#    1056             content = (
#    1057                 stream_resp["message"]["content"]
#    1058                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1059                 else ""
#    1060             )
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\langchain_ollama\chat_models.py:952, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     950 if chat_params["stream"]:
#     951     if self._client:
# --> 952         yield from self._client.chat(**chat_params)
#     953 elif self._client:
#     954     yield self._client.chat(**chat_params)
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\ollama\_client.py:174, in Client._request.<locals>.inner()
#     173 def inner():
# --> 174   with self._client.stream(*args, **kwargs) as r:
#     175     try:
#     176       r.raise_for_status()
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpx\_client.py:868, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     845 """
#     846 Alternative to `httpx.request()` that streams the response body
#     847 instead of loading it into memory at once.
#    (...)
#     853 [0]: /quickstart#streaming-responses
#     854 """
#     855 request = self.build_request(
#     856     method=method,
#     857     url=url,
#    (...)
#     866     extensions=extensions,
#     867 )
# --> 868 response = self.send(
#     869     request=request,
#     870     auth=auth,
#     871     follow_redirects=follow_redirects,
#     872     stream=True,
#     873 )
#     874 try:
#     875     yield response
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\vladb\jupyter-notebooks\github-librarian\.venv\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
# summary_docs, docs = load_documents()


# pprint(len(summary_docs))

# lista  = [doc.metadata['repo_origin'] for doc in summary_docs]

# save_progress(lista)
# Out:
# 434

# %%
summary_docs, docs = load_documents()

# %%
summary_docs, docs = load_documents()
pprint(len(summary_docs))
pprint(len(docs))
# Out:
# 485
# 4339

# %% [markdown]
# #### Embedding and Saving Documents

# %%
embeddings = OllamaEmbeddings \
(
    model=OLLAMA_EMBEDDING_MODEL,
    num_ctx=TOKEN_CONTEXT_LENGTH,
    mirostat_eta = 0.1,
    mirostat_tau = 5.0,
    mirostat = 0,
    tfs_z=1.0
)

# %%
batch_size = 10
db_repo = None
db_summary = None

# %%
for i in tqdm(range(0, len(summary_docs), batch_size), desc="Indexing Summary Documents"):

    batch = summary_docs[i : i + batch_size]
    
    if db_summary is None:
        # Create the store with the first batch
        db_summary = FAISS.from_documents(batch, embeddings)
    else:
        # Add subsequent batches
        db_summary.add_documents(batch)

db_summary.save_local("data/summary")  # type: ignore

for i in tqdm(range(0, len(docs), batch_size), desc="Indexing Repo Documents"):

    batch = docs[i : i + batch_size]
    
    if db_repo is None:
        # Create the store with the first batch
        db_repo = FAISS.from_documents(batch, embeddings)
    else:
        # Add subsequent batches
        db_repo.add_documents(batch)

db_repo.save_local("data/repo")  # type: ignore
# Out:
# Indexing Summary Documents: 100%|██████████| 49/49 [01:24<00:00,  1.73s/it]
# Indexing Repo Documents: 100%|██████████| 434/434 [15:58<00:00,  2.21s/it]

# %%
db_repo = FAISS.load_local("data/repo", embeddings, allow_dangerous_deserialization=True)
db_summary = FAISS.load_local("data/summary", embeddings, allow_dangerous_deserialization=True)

# %%
# db_repo.save_local("data/repo")  # type: ignore
# db_summary.save_local("data/summary")  # type: ignore

# %%
retriever_repo = db_repo.as_retriever()
retriever_summary = db_summary.as_retriever()

# pprint(list((doc.metadata.get('awesome_list_origin'), doc.metadata.get('repo_name'), doc.page_content) for doc in db.max_marginal_relevance_search("fast web app", k = 100)), width=10000)

# pprint(list(f"{doc.metadata.get('repo_name')} ; {val} : {doc.page_content[:200]} " for (doc, val) in db_repo.similarity_search_with_score(QUERY_PREFIX + "python content management system", k=100)), width=1000)
pprint(list(f"{doc.metadata.get('repo_name')} ; {val} : {doc.page_content.splitlines()[0]} " for (doc, val) in db_summary.similarity_search_with_score(QUERY_PREFIX + " web app builder", k=100)), width=1000)

# pprint(db.max_marginal_relevance_search("fast web app", k = 100))
# Out:
# ['streamlit ; 0.9404366612434387 : title: streamlit | text: streamlit is a fast, easy-to-use Python web app builder that allows users to easily create interactive data apps. It offers a simple and Pythonic approach to data visualization and collaboration, with a vibrant community for support and inspiration. ',
#  'pybuilder ; 1.092275857925415 : title: pybuilder | text: pybuilder is a Python build automation tool designed for easy and efficient Python development. It leverages dependency-based programming principles to build build life cycles similar to those found in other popular build tools. PyBuilder offers a powerful plugin mechanism for creating build life cycles similar to those used in Java build tools, allowing for more complex and scalable build processes. The tool is available on the Python 3.9, 3.10, 3.11, 3.12, 3.13, and PyPy 3.8, 3.9, and 3.10 versions. The tool is available via GitHub Actions Workflow, and the PyPI for more information is available at [https://github.com/pybuilder/pybuilder](https://github.com/pybuilder/pybuilder). ',
#  "FuncToWeb ; 1.1024665832519531 : title: FuncToWeb | text: FuncToWeb is a simple, Python-based web application that provides basic web UI functionality. It's designed for quick prototyping and image processing tasks, with a focus on ease of use and efficient file transfer. The application includes input types, special types, file uploads, dynamic lists, and optional fields. It also offers authentication, multiple functions, dark mode, and server options. The application is designed for rapid prototyping, image processing, data science, and high-performance file transfer. ",
#  "webassets ; 1.118947982788086 : title: webassets | text: webassets is a Python web development application that allows you to merge and compress your JavaScript and CSS files. It's designed to be easy to use and maintain, with a well-tested development version. Download a tarball of the development version or install it via `pip install webassets==dev`. ",
#  'werkzeug ; 1.132469892501831 : title: werkzeug | text: werkzeug is a comprehensive web application library providing a powerful and flexible WSGI utility. It offers a rich set of features including a debugger, request object, response object, routing system, and HTTP utilities, making it suitable for building a wide range of end-user applications. The library is designed to be easy to use and maintain, with a focus on providing a robust and extensible solution for building powerful and scalable web applications. ',
#  'pelican ; 1.1707985401153564 : title: pelican | text: pelican is a static site generator written in Python, designed to create web sites without database or server-side programming. It generates static sites that can be served via any web server or hosting service. Features include chronological content, static pages, integration with external services, and a rich plugin ecosystem. The name "Pelican" is an anagram of "calepin," meaning "notebook" in French. ',
#  "masonite ; 1.181882619857788 : title: masonite | text: masonite is a developer-focused tool with a wide range of features for rapid web app deployment and advanced development. It's easy to learn and use, with a clear documentation and a supportive community. ",
#  "flask ; 1.18528151512146 : title: flask | text: flask is a lightweight web application framework designed for quick and easy development. It's built on top of Django and Jinja2, offering a user-friendly interface for building web applications. Flask's core functionality includes suggestions, but the developer is ultimately responsible for choosing tools and libraries. The framework is designed to be easy to use and provides a wide range of extensions to add new features. The Pallets organization supports Flask and its libraries, allowing contributors to contribute to the community and provide feedback. ",
#  'webargs ; 1.1935250759124756 : title: webargs | text: webargs is a Python library for parsing and validating HTTP request objects, with built-in support for popular web frameworks, including Flask, Django, Bottle, Tornado, Pyramid, Falcon, and aiohttp. ',
#  'lektor ; 1.1994906663894653 : title: lektor | text: lektor is a static website generator built using a static file system, allowing for a comprehensive range of Lektor features. It provides a user-friendly admin UI and a minimal desktop app for easy development. To use the Lektor website, refer to the official documentation. ',
#  'py2app ; 1.2035924196243286 : title: py2app | text: py2app is a powerful tool for building standalone applications and plugins on macOS, leveraging Python scripts for creating application and plugin bundles. The repository contains documentation, issues, and a repository, which is currently in progress. The project links are provided. ',
#  "splinter ; 1.2221028804779053 : title: splinter | text: splinter is a simple and consistent API for web application automation. It's designed for easy learning and rapid development, offering a powerful and flexible solution for browser interactions. The API is built with a focus on real-world use cases, while the documentation and changelog provide clear guidance. The API supports multiple automation drivers, making it suitable for a wide range of applications. The example code demonstrates how to use the API to automate browser interactions. ",
#  "Zappa ; 1.2233226299285889 : title: Zappa | text: Zappa is a serverless Python development environment built on AWS Lambda and API Gateway. It allows you to build and deploy serverless applications using Python, Django, and Flask. The environment provides a flexible and scalable solution for hosting web applications, microservices, and other serverless workloads. Zappa's features include automatic scaling, zero-downtime deployments, and a wide range of customization options. ",
#  "flexx ; 1.2319910526275635 : title: flexx | text: flexx is a Python toolkit for creating graphical user interfaces (GUIs), leveraging web technology for rendering applications. It's designed to be a single application framework for desktop applications, web applications, and export to standalone HTML documents, making it versatile and easy to use. The library is available on Readthedocs and Github, and it supports various browsers and internet explorer versions. ",
#  'pywebview ; 1.2337663173675537 : title: pywebview | text: pywebview is a lightweight native webview wrapper that allows you to display HTML content in your desktop application, hiding the GUI. It provides a web component window with built-in HTTP server, DOM support in Python and window management, and native GUI elements like application menu and dialogs. pywebview is available for Windows, macOS, Linux (GTK or QT) and Android. It uses native GUI for creating a web component window, offering advanced features like window manipulation, event system, built-in HTTP server, native GUI elements like application menu and various dialogs, and two-way communication between Javascript and Python and DOM support. pywebview is created by Roman Sirokov. ',
#  "sanic ; 1.2448158264160156 : title: sanic | text: sanic is a Python web server and web framework that provides fast and efficient HTTP server and web application development. It's designed to be easy to build, expand, and scale, making it suitable for a wide range of projects. The project is maintained by the community, and contributions are welcome. ",
#  'django-rest-framework ; 1.270546317100525 : title: django-rest-framework | text: django-rest-framework is a powerful and flexible toolkit for building Web APIs. It offers a wide range of features, including RESTful API endpoints, authentication, serialization, and data management. The framework provides a user-friendly interface for developers to build and deploy RESTful APIs, making it a valuable tool for various applications. ',
#  'nikola ; 1.2725926637649536 : title: nikola | text: nikola is a static website generator that offers a safe, resource-efficient, and flexible way to build websites. It features a wide range of features, including blogs, feeds, archives, comments, and more, along with a robust syntax highlighting system and multilingual support. The website is designed to be easy to use and maintain, with a Python 3.8+ compatible version. ',
#  "websockets ; 1.2735002040863037 : title: websockets | text: websockets is a Python library for building WebSocket servers and clients in Python, focusing on correctness, simplicity, robustness, and performance. It's designed for production use, with a strong emphasis on compliance with RFCs and the development of a well-tested, maintainable, and efficient codebase. The library provides a comprehensive set of documentation, including the `Read the Docs` repository, and is available as part of the Tidelift Subscription. ",
#  'django ; 1.2739005088806152 : title: django | text: django is a high-level Python web framework that encourages rapid development and clean, pragmatic design. ',
#  'fastapi ; 1.2765003442764282 : title: fastapi | text: fastapi is a modern, fast (high-performance), web framework for building APIs with Python based on standard Python type hints. The key features include: ',
#  'sixpack ; 1.2901536226272583 : title: sixpack | text: sixpack is a framework for enabling A/B testing across multiple programming languages. It provides a simple API for client libraries, allowing developers to write code in virtually any language. The core functionality involves exposing a simple API for client libraries, which can be written in virtually any language. The Sixpack API allows for cross-language testing by accepting a unique `client_id` that links a participation to a conversion. The API also supports multiple KPIs, including conversion against a specific KPI. The Sixpack API is available in various languages, including Ruby, Python, JavaScript, PHP, iOS, Go, Perl, C#, Java, Android, and C#. ',
#  'buildout ; 1.2933086156845093 : title: buildout | text: buildout is a project designed to solve 2 problems: ',
#  "Eel ; 1.2938756942749023 : title: Eel | text: Eel is a Python library for making simple offline HTML/JS GUI apps, offering a lightweight and easy-to-use alternative to more complex frameworks like Electron or cefpython. It provides a local webserver, allows you to annotate functions in Python, and offers a robust and well-documented set of tools for writing short and simple GUI applications. The library's core functionality lies in its ability to handle asynchronous operations, making it suitable for tasks such as building simple utility scripts that can be executed in the browser. ",
#  "jet-bridge ; 1.298583984375 : title: jet-bridge | text: jet-bridge is a SaaS application that automatically generates extendable back office for your application, leveraging Jet Bridge's REST API to connect to your database. It's designed for small startups and mature companies, offering a flexible and customizable interface with the ability to extend features and create custom actions. The project is hosted on Jet Admin, a free, open-source SaaS platform, and integrates with various SQL databases. ",
#  "makesite ; 1.2990622520446777 : title: makesite | text: makesite is a simple, lightweight, and magic-free static site generator in Python. It's designed to generate static websites by writing simple, lightweight, and magical-free code. The code is well-documented and easy to understand, with a focus on simplicity and speed. It's suitable for beginners and experienced developers alike. ",
#  'autobahn-python ; 1.3002088069915771 : title: autobahn-python | text: autobahn-python is a Python-based project offering open-source implementations of WebSocket and WAMP for Python 3.7+ and running on Twisted and asyncio. It provides a framework for building and deploying WebSocket and WAMP applications in Python, leveraging the WebSocket protocol and WAMP for real-time communication. The project includes a comprehensive set of binary wheels for various platforms, including Twisted and asyncio, and supports Python 3.7+ and running on CPython and PyPy. ',
#  "Wooey ; 1.3012380599975586 : title: Wooey | text: Wooey is a simple web interface designed to run command-line Python scripts. It's designed to be easy to use for data analysis, file processing, and other tasks. The interface allows users to automate data workflows, enabling them to easily integrate Python scripts into their workflows without needing to use specific programming languages. The interface is also designed to be user-friendly, with a clear and intuitive layout. The demo-server is available for testing and demonstration. ",
#  "beaker ; 1.3051190376281738 : title: beaker | text: beaker is a web session and general caching library that includes WSGI middleware for use in web applications. It's designed to handle storing for various Python objects that can be pickled with optional backends on a fine-grained basis. Beaker was built largely on the code from MyghtyUtils, then refactored and extended with database support. It offers fast, robust performance, multiple reader/single writer lock system, and cache backends including dbm, file, memory, memcached, Redis, MongoDB, and database (using SQLAlchemy for multiple-db vendor support). Features include Fast, robust performance, multiple reader/single writer lock system, and cache backends include dbm, file, memory, memcached, Redis, MongoDB, and database (Using SQLAlchemy for multiple-db vendor support). It's also designed to be easily integrated with WSGI capable frameworks and is automatically used by `Pylons` and `TurboGears` for caching. ",
#  "Wooey ; 1.317052960395813 : title: Wooey | text: Wooey is a simple web interface designed to run command-line Python scripts. It's designed to be easy to use for data analysis, file processing, and other tasks. The interface allows users to easily automate data workflows, enabling them to collaborate with colleagues without needing to use complex language-specific tools like Galaxy. The interface is also designed to be easily wrapped in Python, making it suitable for applications that don't require specific language support. For installation and other instructions, check out our documentation or give Wooey a test drive at our demo-server! ",
#  "Wooey ; 1.3172223567962646 : title: Wooey | text: Wooey is a simple web interface designed to run command-line Python scripts for data analysis, file processing, and other tasks. It's designed to be easy to use, allowing data analysts to easily automate workflows and collaborate with colleagues without needing to use complex language-specific tools. The interface provides a user-friendly experience for data analysis, enabling data scientists to easily integrate Python scripts into their workflows. The demo-server allows users to test the interface and experience its capabilities. ",
#  "falcon ; 1.3178346157073975 : title: falcon | text: falcon is a minimalist ASGI/WSGI framework for building mission-critical REST APIs and microservices, with a focus on reliability, correctness, and performance at scale. It's designed to be clean, easy to use, and supports various `WSGI` and `ASGI` server types, making it suitable for a wide range of applications. Falcon's core features include its clean design, support for HTTP and REST architectures, and its ability to handle complex routing and state management. ",
#  'tornado ; 1.3240896463394165 : title: tornado | text: tornado is a Python web framework and asynchronous networking library designed for handling large-scale web applications. It\'s built on non-blocking network I/O, enabling it to scale to tens of thousands of open connections, making it ideal for long-running web applications requiring a long-lived connection. The framework provides a simple "Hello, world" example web app for Tornado, demonstrating its capabilities in handling asynchronous requests and network interactions. ',
#  "copier ; 1.3264535665512085 : title: copier | text: copier is a library and CLI app for rendering project templates. It works with local paths and Git URLs, and generates beautiful output and handles overwriting existing files. It's easy to install and use, and it provides a clean and organized way to create templates. The project is built using a Jinja2 templating system, which is a common and efficient approach for creating templates. The project is designed to be easy to learn and use, with clear instructions and helpful documentation. ",
#  'uvicorn ; 1.329234004020691 : title: uvicorn | text: uvicorn is a Python ASGI web server for Python, designed to provide a common tooling environment for asynchronous code. It supports HTTP/1.1, HTTP/2, and WebSockets, and is built with a focus on ease of use and integration with existing frameworks. The ASGI protocol decouples the server from the application, allowing for more flexible and robust web applications. ',
#  'Stream-Framework ; 1.3297815322875977 : title: Stream-Framework | text: Stream-Framework is a Python library that enables you to build activity streams and newsfeeds using Cassandra and/or Redis. It offers a user-friendly API for creating and managing these systems, with a focus on scalability and ease of use. The library provides a web service for building scalable newsfeeds and activity streams at [Stream][stream-url]. ',
#  'flower ; 1.3318214416503906 : title: flower | text: flower is a web application for monitoring and managing Celery clusters. It provides real-time information about Celery workers and tasks, and offers remote control and worker status monitoring. It also supports HTTP Basic Authentication, Google, and GitHub integration. The application is designed for ease of use and deployment. ',
#  "flask-api ; 1.332287073135376 : title: flask-api | text: flask-api is a simple, built-in Flask API that provides a browsable web API for Flask applications. It supports status codes like 'This project is in maintenance mode' and 'The original author has shifted their focus to API Star'. The API is designed to be easy to use and provides a good balance between functionality and ease of use. ",
#  "wagtail ; 1.3366005420684814 : title: wagtail | text: wagtail is a free, open-source content management system built on Django, with a strong community and commercial support. It offers a fast, attractive interface, complete control over front-end design and structure, and scalable to millions of pages and thousands of editors. Features include a fast, attractive interface, complete control over front-end design and structure, and a fast out-of-the-box, cache-friendly when needed. Wagtail is supported by Python 3, PostgreSQL, MySQL, and SQLite, with JSON1 as the database backend. It's compatible with Django 4.2.x, 5.2.x, and 6.0.x, and supports PostgreSQL, MySQL, MariaDB, and SQLite. Wagtail is sponsored by Torchbox, and it's available for commercial support through madewithwagtail.org. The project is developed by a passionate community of developers, and it's available for free use and modification. ",
#  "flask-admin ; 1.3447502851486206 : title: flask-admin | text: flask-admin is a simple, easy-to-use Flask extension that adds admin interfaces to Flask applications. It's inspired by Django but implemented in a way that allows developers to control the look, feel, and functionality of their applications. The extension offers a simple file management interface and a Redis client console, making it a convenient tool for building admin interfaces. ",
#  "bokeh ; 1.3515136241912842 : title: bokeh | text: bokeh is a powerful interactive visualization library for modern web browsers, offering elegant and concise construction for versatile graphics and high-performance interactivity across large or streaming datasets. It's a great tool for creating interactive plots, dashboards, and data applications quickly and easily.  ",
#  "PySimpleGUI ; 1.3519233465194702 : title: PySimpleGUI | text: PySimpleGUI is a free, open-source software package that allows users to create and manage applications, including web applications, desktop applications, and more. It's designed to be easy to use and provides a comprehensive set of tools for development, testing, and deployment. The project has been around for over 10 years and has been a source of inspiration for countless developers. The release of PySimpleGUI 5 brought significant improvements to the project's functionality and stability, leading to a more robust and user-friendly experience. The project has been a valuable resource for developers seeking to build and deploy applications. ",
#  'django-compressor ; 1.3523883819580078 : title: django-compressor | text: django-compressor is a powerful and flexible Django template compressor that combines JavaScript and CSS in a single, easy-to-use solution. It supports compilers like coffeescript, LESS, and SASS, and offers a wide range of configurable filters for CSS rewrites, including absolute paths, inline content, and custom filters. The default filter for CSS rewrites is absolute, while the concatenation and compression process can be run manually using Django management. The configuration and extensibility of Django Compressor are also highlighted. ',
#  "flask-admin ; 1.3528341054916382 : title: flask-admin | text: flask-admin is a simple, easy-to-use Flask extension for adding admin interfaces to Flask applications. It's inspired by Django but implemented in a way that allows developers to control the look, feel, and functionality of their applications. The extension offers a simple file management interface and a Redis client console, making it a convenient tool for building admin interfaces. It's designed for ease of use and is actively maintained by the Pallets team. ",
#  "pluginbase ; 1.352881669998169 : title: pluginbase | text: pluginbase is a Python module that enables the development of flexible plugin systems in Python. It provides a module for creating plugins, allowing developers to build custom plugins that can be used in various applications. The module's core functionality involves loading a plugin source file, making it easy to create plugins with different configurations. ",
#  'flask-assets ; 1.3536218404769897 : title: flask-assets | text: flask-assets is a library that integrates with the webassets library, providing support for merging, minifying, and compiling CSS and Javascript files. This allows for efficient and maintainable code, making it easier to integrate with various web applications. ',
#  'uvicorn ; 1.3546348810195923 : title: uvicorn | text: uvicorn is a Python ASGI web server for Python, designed to provide a common tooling environment for asynchronous code. It supports HTTP/1.1, HTTP/2, and WebSockets, and is built using a Cython-based framework. The ASGI protocol decouples the server from the application, allowing for interoperability and a more robust ecosystem of web servers and application frameworks. The ASGI server is available on GitHub and is designed with care and is BSD-licensed. ',
#  "Bender ; 1.355289340019226 : title: Bender | text: Bender is an abstraction layer over MetalPerformanceShaders for neural network development, offering a flexible and easy-to-use framework for working with neural networks on mobile devices. It allows developers to define and run neural network models using the most common layers like Convolution, Pooling, FullyConnected, and some normalizations, while also supporting loading models trained on other frameworks like TensorFlow or Caffe2. Bender's API provides a convenient way to define and run neural network operations, including model loading, input/output mappings, and parameter translation. The repository includes detailed documentation, examples, and a GitHub repository for further exploration. ",
#  'langid.py ; 1.3558509349822998 : title: langid.py | text: langid.py is a standalone Language Identification (LangID) tool that is pre-trained on 97 languages. It is designed for ease of use and deployment as a web service. The tool supports various language detection methods, including the `fapws3` web server, and is compatible with both Python 2 and Python 3. It is a WSGI-compliant tool that uses `fapws3` as a web server, and it can be used with both Python 2 and Python 3. The tool provides a simple command-line interface for identifying languages, and it can be used as a library for language identification. ',
#  'sandman2 ; 1.356504201889038 : title: sandman2 | text: sandman2 is a RESTful API service built using Python and SQLAlchemy, designed to connect to and interact with various databases. It provides a user-friendly API for accessing and managing data from various sources, including SQLite, PostgreSQL, and other databases. The service is designed to be easily integrated into existing applications and is free of any code changes. ',
#  "mkdocs ; 1.3614742755889893 : title: mkdocs | text: mkdocs is a fast, simple, and gorgeous static site generator for building project documentation. It's designed for easy use and can be extended with third-party themes, plugins, and Markdown extensions. The built-in themes, third-party themes, and Markdown extensions make it a great choice for creating documentation for various purposes. The project welcomes contributions from developers and users in the open source community. ",
#  "eve ; 1.3622801303863525 : title: eve | text: eve is a Python REST API framework designed for human beings, offering a simple and customizable way to build and deploy RESTful web services. It supports MongoDB, SQL, and backends via community extensions, making it easy to build and deploy highly customized, fully featured RESTful Web Services. The framework provides native support for MongoDB, SQL, and backends via community extensions, making it easy to configure and fine-tune API access. It's a simple and open-source project with a strong focus on REST principles and a robust framework for building and deploying custom web services. ",
#  'scons ; 1.3627066612243652 : title: scons | text: scons is a powerful open-source software construction tool that automates the process of building software, including documentation files, and provides a robust and reliable solution for various programming languages and file types. Its features include configuration files, dependency analysis, built-in support for C, C++, D, Java, FORTRAN, Yacc, Lex, Qt, and SWIG, and easy extensibility through user-defined builders. The tool is designed for cross-platform builds, and its integration with Microsoft Visual Studio, including generation of `.dsp`, `.dsw`, `.sln`, and `.vcproj` files, is a significant advantage. The tool is available on the Python installer, and the SCons user guide provides detailed instructions for installation and usage. Contributing to SCons is encouraged, and the community welcomes bug reports and feature requests. The SCons project actively welcomes bug reports and feature requests, and the mailing list is '
#  'available for developers of SCons. ',
#  'toapi ; 1.3645179271697998 : title: toapi | text: toapi is a repository for API endpoints, including web site APIs, and provides documentation, awesome, and organization features. It supports automatic conversion of HTML web sites to API service endpoints, caching every page of source sites, and supports merging multiple web sites into a single API service. The repository includes installation instructions, usage examples, and a pull request for testing. ',
#  "flask-admin ; 1.3645352125167847 : title: flask-admin | text: flask-admin is a simple, easy-to-use Flask extension for adding admin interfaces to Flask applications. It's inspired by Django but implemented in a way that allows developers to control the look, feel, and functionality of their applications. The extension offers a simple file management interface and a Redis client console, making it suitable for building admin interfaces of any complexity. It's a well-tested and production-ready project with examples and pull-requests available. ",
#  'uvicorn ; 1.3648595809936523 : title: uvicorn | text: uvicorn is an ASGI web server for Python, designed to provide a common tooling environment for asynchronous code. It supports HTTP/1.1, WebSockets, and provides a lightweight background task for handling long-running operations. The ASGI protocol decouples the server from the application framework, allowing for interoperability and a more robust ecosystem. ',
#  "hug ; 1.3649507761001587 : title: hug | text: hug is a Python-driven API development framework that simplifies Python API development by providing a streamlined and efficient way to create simple, succinct, and fast Python-based APIs. Its design objectives are to make developing Python-based APIs as simple as possible, encouraging code self-documentation, and achieving fast performance. The framework's features include a well-defined design objectives, a comprehensive set of tools for building and testing APIs, and a robust security and quality assurance process. ",
#  'grab ; 1.3661671876907349 : title: grab | text: grab is a Python web scraping framework providing network requests, scraping web sites, and processing the scraped content. It offers automatic cookies, HTTP/S proxy with/without authorization, IDN support, tools for working with web forms, and easy multipart file uploading. The library is designed for efficient and reliable network scraping. ',
#  "cli ; 1.3669497966766357 : title: cli | text: cli is a command-line HTTP client designed for human-friendly interaction with web services. It's built with simple and natural syntax, formatted output, and supports JSON support, making it suitable for testing, debugging, and interacting with APIs and HTTP servers. The `http` and `https` commands allow for creating and sending arbitrary HTTP requests, and the `pie.dev/put` example demonstrates its features. The community and support channels are available for questions and requests. ",
#  'cornice ; 1.3678665161132812 : title: cornice | text: cornice is a project focused on building and documenting Web Services with Pyramid. The project aims to provide developers with tools to build and document web services, enabling them to create robust and scalable solutions. The project is currently in development and seeks a new steward to maintain and update the project. ',
#  'micawber ; 1.3683276176452637 : title: micawber | text: micawber is a library for extracting rich content from URLs, providing methods for parsing blocks of text and HTML, and replacing links with embedded content. It offers examples of how to use the library to retrieve and process various types of content. ',
#  "python-user-agents ; 1.374585747718811 : title: python-user-agents | text: python-user-agents is a Python library providing a simple way to identify and detect devices like mobile phones, tablets, and their capabilities by parsing user agent strings. It's easy to use and available on PyPI, with various basic information available through browser, device, and OS attributes. The library offers a basic set of attributes for identifying popular platforms and devices, and it also provides a few more advanced attributes. The library is available for both iOS and Android, and it supports touch capabilities. ",
#  'httpx ; 1.3774762153625488 : title: httpx | text: httpx is a Python library for building HTTP client applications, offering a comprehensive set of features for both HTTP/1.1 and HTTP/2. It provides a standard API, a command-line client, HTTP/1.1 and HTTP/2 support, and a robust testing framework. The library is designed for ease of use and integration with other Python libraries. ',
#  'django-allauth ; 1.3785840272903442 : title: django-allauth | text: django-allauth is a comprehensive and integrated Django application that addresses social authentication, registration, account management, and third-party (social) authentication. It offers a fully functional and integrated solution for both local and social authentication, with a focus on ease of use and customization. The application provides a robust set of features, including account functionality, social login, enterprise-ready support, and a customizable development environment. ',
#  'pythonnet ; 1.3836627006530762 : title: pythonnet | text: pythonnet is a Python-based package that provides a powerful application scripting tool for .NET developers. It allows Python code to interact with the CLR, and may also be used to embed Python into .NET applications. The package offers a seamless integration with the .NET Common Language Runtime (CLR) and provides a powerful application scripting tool for .NET developers. ',
#  'hydra ; 1.3881105184555054 : title: hydra | text: hydra is a framework for elegantly configuring complex applications.  ',
#  'django-grappelli ; 1.3885390758514404 : title: django-grappelli | text: django-grappelli is a grid-based alternative to the Django administration interface, designed to provide a more modern and user-friendly experience for Django developers. It leverages the Django 5.x stable release and is compatible with Django 4.2 LTS. The repository contains documentation, releases, and a GitHub repository for further development. ',
#  'authlib ; 1.388637661933899 : title: authlib | text: authlib is a Python library for building OAuth and OpenID Connect servers, offering a comprehensive set of features for managing authentication and authorization. It supports Migrations, Sponsors, Features, and other functionalities, making it suitable for building secure and scalable applications. The library provides a user-friendly interface for managing authentication and authorization, including integration with third-party providers like Auth0 and Tidelift. ',
#  "toga ; 1.3890788555145264 : title: toga | text: toga is a Python native, OS native GUI toolkit. It's designed for creating user-friendly and interactive applications using Python. The minimum requirements are that each backend must have specific requirements and pre-requisites. The Quickstart guide provides a demonstration of the capabilities of Toga, including displaying sample widgets. The documentation can be found on Read The Docs. The financial support is provided by BeeWare's AI development. The community is fostered through the Toga Community Code of Conduct. Contributing is encouraged, and the contribution guide details how to set up development environments and other requirements. ",
#  'shiv ; 1.3900811672210693 : title: shiv | text: shiv is a command-line utility for building fully self-contained Python zipapps, designed for distributing Python applications efficiently. It provides a fast and easy way to create and manage zipapps, with a focus on cross-platform compatibility. The system requirements are specified, and a simple CLI example is provided. The installation process involves downloading a release from GitHub and using `pip` or `pypi` to install shiv. The development process involves creating a virtual environment, installing necessary packages, and then building the zipapp using `python3 -m venv venv` and `python3 -m pip install --upgrade build`. The documentation is available in a `requirements.txt` file. The project is not guaranteed to be cross-compatible with other architectures, and the `pyz` file is only available on macOS. The project is also designed to extract itself into a `~/.shiv` directory, unless overridden by `SHIV_ROOT`. ',
#  "feincms ; 1.392673373222351 : title: feincms | text: feincms is a Django-based CMS that allows users to create and manage their own content. It's designed to be easy to use, offering a flexible and powerful framework for structuring and organizing content. The CMS provides a rich text area, a media library, and templates, making it suitable for a wide range of content types. While the CMS is still under development, it's considered a very good and simple content management system. ",
#  "flask-debugtoolbar ; 1.3935147523880005 : title: flask-debugtoolbar | text: flask-debugtoolbar is a Flask extension that injects debugging information into rendered HTML pages. It's a port of the excellent Django debug toolbar, providing a customizable sidebar with configurable panels for debugging. This extension is part of the Pallets Community Ecosystem, enabling community maintenance of related projects. If you are interested in helping maintain this project, please contact the Pallets Discord server [discord]. ",
#  "django-rules ; 1.3969449996948242 : title: django-rules | text: django-rules is a small, powerful app that provides object-level permissions to Django, without requiring a database. It's a generic framework for building rule-based systems, similar to `decision trees`, that can be used as a standalone library in other contexts and frameworks. It offers features like documented, tested, reliable, and easy to use, with a versatile Django citizen. The app is designed for efficient and smart rule-based applications, with advanced features like invocation context and storage for arbitrary data, skipping evaluation of predicates under specific conditions, logging of evaluated predicates and more! ",
#  "gevent ; 1.397289752960205 : title: gevent | text: gevent is a powerful and versatile project that allows you to build and deploy applications with a single codebase. It's built using a modular architecture, making it easy to adapt to different projects and environments. The project provides a comprehensive set of tools and resources for developers, including documentation, bug tracking, and communication channels. Gevent is designed to be a valuable asset for anyone who wants to build and deploy applications quickly and efficiently. ",
#  'devpi ; 1.3975377082824707 : title: devpi | text: devpi is a Python package that provides a web and search interface for PyPI server and packaging/testing/release tools. It enables users to serve consistent caching indexes and build user or team-based indexes, which can inherit from existing packages or from the PyPI site. The repository contains three packages: `devpi-server`, `devpi-web`, and `devpi-client`, each with its own set of commands for various tasks. For initial setup, the repository provides more documentation. ',
#  "graphene ; 1.4016313552856445 : title: graphene | text: graphene is a Python library for building GraphQL schemas/types, making it easy to use and integrate with other frameworks. It's designed for data-agnostic and easy-to-use GraphQL APIs, with built-in support for Relay. The library is compatible with various GraphQL clients, including Relay, Apollo, and gql. It's also fully compatible with the GraphQL specification, making it a reliable and versatile tool for developers. ",
#  'cookiecutter ; 1.4023441076278687 : title: cookiecutter | text: cookiecutter is a powerful command-line utility for creating Python package projects, offering a user-friendly and versatile solution for generating projects from templates. It supports cross-platform use, user-friendliness, and multilingual support, making it suitable for various programming languages and projects. The utility provides a comprehensive set of features, including quick start, GitHub templates, local templates, and a community-driven support system, making it a valuable tool for developers. ',
#  "scrapy ; 1.4067981243133545 : title: scrapy | text: scrapy is a web scraping framework for extracting structured data from websites. It's cross-platform and requires Python 3.10+. It's maintained by Zyte_ (formerly Scrapinghub) and `many other contributors`. ",
#  "enaml ; 1.4082129001617432 : title: enaml | text: enaml is a programming language and framework for creating professional-quality user interfaces with minimal effort. It's a declarative programming language with a Pythonic flavor, offering a wide range of widgets and constraints-based layout engines. Enaml facilitates easy prototyping and customization of GUIs, enabling developers to build native applications for various platforms. It supports Python (3.10+), Qt (5.9+), PySide, and is licensed under the `Modified BSD License`. The `Getting Started` chapter provides a foundational overview of Enaml's capabilities. The `Enaml documentation` includes examples and tutorials for various use cases. The `Employee Tutorial` demonstrates how constraints and validators can be used to create easy-to-use and professional-looking applications. ",
#  "requests ; 1.4106643199920654 : title: requests | text: requests is a simple, yet elegant HTTP library that supports easy HTTP/1.1 requests, with no manual add-ons or configuration. It's widely used in Python for building robust and reliable HTTP-speaking applications. The library offers a wide range of features, including keep-alive, connection pooling, international domains, and session persistence, making it suitable for building web applications. The library is available on PyPI and is supported by the GitHub repository. ",
#  "tinydb ; 1.41111159324646 : title: tinydb | text: tinydb is a lightweight document-oriented database optimized for small apps, designed to be simple and fun to use. It's built using pure Python and has no external dependencies, making it suitable for small projects. The repository provides detailed documentation, example code, and a discussion forum for developers to contribute and share ideas. ",
#  "django-debug-toolbar ; 1.411161184310913 : title: django-debug-toolbar | text: django-debug-toolbar is a configurable set of debug panels that display information about the current request/response and when clicked, providing more details about the panel's content. ",
#  'diagrams ; 1.412061095237732 : title: diagrams | text: diagrams is a Python library for creating and visualizing cloud architecture diagrams, offering a user-friendly interface for prototyping and understanding cloud infrastructure. It supports various providers, including AWS, Azure, GCP, and Kubernetes, and allows for the creation of detailed diagrams to track changes and visualize architecture evolution. The library provides a convenient way to track the architecture changes in version control systems. ',
#  'python-lambda ; 1.4121519327163696 : title: python-lambda | text: python-lambda is a toolset for developing and deploying serverless Python code in AWS Lambda. ',
#  "django-activity-stream ; 1.4123210906982422 : title: django-activity-stream | text: django-activity-stream is a mechanism for generating and displaying activities, designed to handle various actions and follow different activity sources. It's built on the principle of creating streams of interesting actions and can be used to emulate the GitHub dashboard. The specification outlines the four main components of an action, including actors, verbs, action objects, and target objects, and defines a generic foreign key for each. This allows for the creation of actions that can be represented by any Django model in the project. The specification also details the naming conventions for the components, emphasizing the importance of the Activity Streams Spec. ",
#  "django-pipeline ; 1.4184141159057617 : title: django-pipeline | text: django-pipeline is a powerful asset packaging library for Django, providing both CSS and JavaScript concatenation and compression, built-in JavaScript template support, and optional data-URI image and font embedding. It's easy to install and use, and it's designed for efficient compilation and compression of assets. ",
#  "MechanicalSoup ; 1.4202775955200195 : title: MechanicalSoup | text: MechanicalSoup is a Python library for automating interaction with websites, offering a similar API to Requests and Beautiful Soup. It's built on Python's Requests and Beautiful Soup frameworks, and is actively maintained by a small team. It's designed to be a project that is actively maintained by a small team, including `@hemberger` and `@moy`. ",
#  "xlwings ; 1.4204299449920654 : title: xlwings | text: xlwings is a powerful and versatile AI model built on the Gemma library. It's designed to be a versatile tool for a wide range of applications, including image generation, text summarization, and code generation. Its architecture is based on the Transformer model, making it capable of understanding and generating natural language. ",
#  'hypercorn ; 1.422389030456543 : title: hypercorn | text: hypercorn is a web server based on the sans-io hyper, built on the `h11` library, that supports HTTP/1, HTTP/2, WebSockets (over HTTP/1 and HTTP/2), ASGI, and WSGI specifications. Hypercorn can optionally serve the current draft of the HTTP/3 specification using the `aioquic` library. It is initially part of the Quart library before being separated into a standalone server. Hypercorn is available via `pip install hypercorn` and can be installed via `pip install hypercorn[h3]`. It is developed on `Github` and is supported by `tox` for testing. The documentation is the best place to start, and the `issue` section provides a link to the issue tracker. ',
#  "peewee ; 1.4233417510986328 : title: peewee | text: peewee is a simple and small ORM that is easy to learn and use. It features a small, expressive ORM, supports SQLite, MySQL, and PostgreSQL, and offers a wide range of `extensions` for customization. It's a good starting point for beginners and is recommended for its ease of use and intuitive design. ",
#  'requests-html ; 1.4259040355682373 : title: requests-html | text: requests-html is a simple and intuitive library for parsing HTML, making it easy to scrape websites and extract data. It provides full JavaScript support, CSS selectors, XPath selectors, and mock-agent behavior, along with automatic following of redirects and connection pooling. The requests library offers a range of features, including Markdown export, tutorial & usage, and a list of links on the page. ',
#  'blinker ; 1.4280004501342773 : title: blinker | text: blinker is a fast dispatching system that allows any number of interested parties to subscribe to events, or "signals". It\'s built in Python and is part of the Pallets Community Ecosystem. Pallets is a community-driven organization that maintains Flask; Pallets-Eco enables community maintenance of related projects. If you are interested in helping maintain this project, please reach out on [the Pallets Discord server][discord]. ',
#  'spyder ; 1.431633710861206 : title: spyder | text: spyder is a powerful scientific environment developed by Pierre Raybaut and Carlos Córdoba, built in Python and designed for scientists, engineers, and data analysts. It offers a unique combination of advanced editing, analysis, debugging, and profiling functionality, with its built-in editor, interactive console, documentation viewer, variable explorer, and development tools. Spyder is available for download as part of Anaconda distribution, and it is supported by the Open Collective: ',
#  'mixer ; 1.4322383403778076 : title: mixer | text: mixer is a powerful tool for generating instances of Django or SQLAlchemy models, offering a fast and convenient way to test and replace data. It supports various features, including automatic generation, randomization, and custom schemes. The tool is well-documented, and its support for Python 2.7 and later is a significant advantage. ',
#  'configobj ; 1.4323387145996094 : title: configobj | text: configobj is a Python 3+ compatible port of the configobj library, developed by Michael Foord and Rob Dennis. This library provides a comprehensive set of tools for testing and building Python applications, including tests, documentation, and a GitHub CI/CD pipeline. The project was initially developed for the GitHub CI/CD Pipeline, and the last maintenance release was released in 2023. ',
#  'pyinfra ; 1.4329354763031006 : title: pyinfra | text: pyinfra is a powerful Python shell command-line tool designed for running Python code on servers. It offers fast execution, instant debugging, and idempotent operations, making it ideal for deploying Python applications and scripts. The tool supports SSH, local machine, and Docker containers, and provides a comprehensive set of features for automation and scripting. ',
#  'mailer ; 1.4358978271484375 : title: mailer | text: mailer is a Python library for sending emails from your application, offering ease of use and flexibility for creating and managing mail delivery mechanisms. It simplifies the process of sending emails through various transport options, including SMTP, Amazon SES, sendmail, and direct on-disk mbox/maildir. The library provides a comprehensive set of configuration options for managing multiple delivery methods and choosing the most appropriate one for each message. ',
#  'html5lib-python ; 1.437096357345581 : title: html5lib-python | text: html5lib-python is a pure-python library for parsing HTML, designed to conform to the HTML specification by using the "WhatWG" HTML specification. It supports simple usage with a "simple usage" pattern, and the "accelerated ElementTree" implementation is available for Python 2.x. Two other tree types are supported: "xml.dom.minidom" and "lxml.etree". To use an alternative format, specify the name of a treebuilder, and the `urllib2` (Python 2) charset should be passed into html5lib. The `urllib2` charset should be passed into html5lib. The `xml.etree.cElementTree` implementation is available for Python 2.x. To have more control over the parser, create a parser object explicitly. When using with `urllib2`, the charset from HTTP should be passed into html5lib. When using with `urllib.request`, the charset from HTTP should be passed into html5lib. To have more control over the parser, create a parser object '
#  "explicitly. When you're instantiating parser objects, pass a treebuilder class as the `tree` keyword argument to use an alternative document format. The `lxml` implementation is available as a tree format (CPython 2.7+, CPython 3.5+ and PyPy). The `genshi` treewalker is not a builder, and `chardet` can be used as a fallback. The `html5lib-tests` repository contains unit tests for the `pytest` and `mock` libraries and can be run using `pytest`. The `tox` utility can be found on PyPI. The `html5lib-discuss mailing list` repository provides a discussion of the `html5lib-discuss` mailing list. ",
#  'waitress ; 1.440449595451355 : title: waitress | text: waitress is a production-quality pure-Python WSGI server with no dependencies except those that live in the Python standard library. It runs on CPython on Unix and Windows under Python 3.9+. It is also known to run on PyPy 3 (version 3.9 compatible python and above) on UNIX. It supports HTTP/1.0 and HTTP/1.1. For more information, see the "docs" directory of the Waitress package or visit https://docs.pylonsproject.org/projects/waitress/en/latest/ ',
#  'flask-restful ; 1.4405291080474854 : title: flask-restful | text: flask-restful is a powerful and versatile library for building RESTful APIs. It provides a comprehensive set of tools and resources to help you design, build, and maintain your API. This guide covers the fundamentals of Flask-RESTful, including its core concepts, data structures, and best practices for creating efficient and scalable APIs. ']

# %%
# retriever = vector_store.as_retriever()

# %%
# ddocs = retriever.

# %%
# # pprint(list(x.previous_siblings for x in soup.select("ul")))
# # pprint(list(zip((x.previous_sibling for x in soup.select("ul")), soup.select("ul"))))




# tech_lists = soup.select("ul")

# dict_tech_lists = {}

# for tech_list in tech_lists:
    
#     links = []

#     try:

#         # (sub)title of list
#         subtitle = tech_list.find_all_previous()[0].text.splitlines()[0]

#         for item in tech_list.select("li"):
            
#             link : str = item.a.get("href", None)  # type: ignore
            
#             if link.startswith("#"):
#                 continue

#             # im currently ignoring the other "awesomez-..." lists featured
#             if "awesome-" in link:
#                 # print("\t---",link.replace("https://github.com/", ""), "---")
#                 continue

#             if link.startswith("https://github.com/"):
                
#                 if link.endswith("/"):
#                     link = link[:-1]

#                 link = link.replace("https://github.com/", "")


#                 links.append(link)

#     except:

#         continue

#     if len(links) > 0:

#         dict_tech_lists.update({subtitle : links})

#         # print(subtitle)
#         # pprint(links)

# pprint(dict_tech_lists)
